# %%
import pandas as pd
import numpy as np
import nltk
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle('../data/out/data.pkl')
df
# Out:
#                                               name       date  revenue  \
# 0                                 Blacksmith Scene 1893-01-01      NaN
# 1                                       Miss Jerry 1894-10-09      NaN
# 2      Corbett and Courtney Before the Kinetograph 1894-11-17      NaN
# 3                                           La Mer 1895-01-01      NaN
# 4                              Autour d'une cabine 1895-01-01      NaN
# ...                                            ...        ...      ...
# 42193                                     Kisaragi        NaT      NaN
# 42194                                  Mother Fish        NaT      NaN
# 42195                         Deewana Tere Naam Ka        NaT      NaN
# 42196                                  Hunter Prey        NaT      NaN
# 42197                            The Leopard Woman        NaT      NaN
#
#           runtime               languages                   countries  \
# 0        0.566667           [Silent film]  [United States of America]
# 1             NaN           [Silent film]  [United States of America]
# 2             NaN           [Silent film]  [United States of America]
# 3        0.633333           [Silent film]                    [France]
# 4       15.000000           [Silent film]                    [France]
# ...           ...                     ...                         ...
# 42193  108.000000                      []                          []
# 42194   92.000000            [Vietnamese]                          []
# 42195  140.000000                 [Hindi]                          []
# 42196   90.000000                      []                          []
# 42197   70.000000  [English, Silent film]  [United States of America]
#
#                                                   genres  \
# 0                [Black-and-white, Indie, Short, Silent]
# 1                [Black-and-white, Indie, Short, Silent]
# 2                [Black-and-white, Indie, Short, Silent]
# 3      [Black-and-white, Documentary, Indie, Short, S...
# 4              [Animation, Comedy, Indie, Short, Silent]
# ...                                                  ...
# 42193                                  [Comedy, Mystery]
# 42194                                            [Drama]
# 42195                                            [Drama]
# 42196                                  [Science Fiction]
# 42197                                  [Romance, Silent]
#
#                                                  summary  \
# 0      The scene is all filmed from a stationary came...
# 1      After finding out that her father is suffering...
# 2      James J. Corbett and Peter Courtney both take ...
# 3      This 38 second film has a very simple plot in ...
# 4      The film consists of a series of animations on...
# ...                                                  ...
# 42193  One year after the suicide of C-list model Kis...
# 42194  Mother Fish follows the story of a middle-aged...
# 42195  Deewana Tere Naam Ka is a family drama, featur...
# 42196  A group of elite interstellar commandos crash ...
# 42197  The story is set in Africa. Two rival European...
#
#                                                  phrases
# 0               [anvil, beer, blacksmith, camera, metal]
# 1      [editor, falls, financial problems, hamilton, ...
# 2                                         [boxing, hero]
# 3                                   [film, jetty, water]
# 4      [beach, boat, diving, dog, film, play, swimmin...
# ...                                                  ...
# 42193                      [death, model, suicide, talk]
# 42194  [boat, death, engine, fish, food, imdb, led, m...
# 42195  [danny denzongpa, drama, family, jagdeep, lead...
# 42196  [ai, bit, bounty hunter, breaks loose, command...
# 42197  [africa, attempt fails, britain, british, dese...
#
# [42198 rows x 9 columns]

# %% [markdown]
# ### Genres column exploration

# %%
genres = df['genres'].dropna()

# %%
# total number of genres
genres.explode().nunique()
# Out:
# 343

# %%
#distribution of top 50 common genres
dist = genres.explode().value_counts(ascending = True)
dist[-50:].plot(kind = 'barh',figsize = (8,10))
# Out:
# <AxesSubplot:>

# %%
df = df.dropna(subset = ['genres'])

# %% [markdown]
# ### Baseline model

# %%
def summary_preprocessing(plot):
    
    #remove punctuation
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    no_punct = plot.apply(lambda x: tokenizer.tokenize(x))
    
    #remove stopwords
    nltk.download('stopwords')
    stop_words = set(nltk.corpus.stopwords.words('english'))
    no_stopwords = no_punct.apply(lambda x: ' '.join([w for w in x if w not in stop_words]))
    
    return no_stopwords

# %%
def model(summary,genres):
    #tf-idf vectorizer
    multilabel_binarizer = sklearn.preprocessing.MultiLabelBinarizer()
    multilabel_binarizer.fit(genres)
    label = multilabel_binarizer.transform(genres)
    xtrain, xval, ytrain, yval = train_test_split(summary, label, test_size=0.2, random_state=9)
    tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10000)
    xtrain_tfidf = tfidf_vectorizer.fit_transform(xtrain)
    xval_tfidf = tfidf_vectorizer.transform(xval)
    
    #OneVsRest classifier
    lr = sklearn.linear_model.LogisticRegression()
    clf = OneVsRestClassifier(lr,n_jobs = 8)
#     scores = cross_validate(clf, xtrain_tfidf, ytrain, scoring=scoring)
    clf.fit(xtrain_tfidf,ytrain)
    y_pred = clf.predict(xval_tfidf)
    
    
    #evaluation
    f1 = sklearn.metrics.f1_score(yval, y_pred, average="micro")
    return f1, multilabel_binarizer.inverse_transform(yval), multilabel_binarizer.inverse_transform(y_pred)

# %%
df['processed_summary'] = summary_preprocessing(df['summary'])
f1_summary, genre_summary, predict_genre_summary = model(df['processed_summary'],df['genres'])
# Out:
# [nltk_data] Downloading package stopwords to /home/humiao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
phrases_joined = df['phrases'].apply(lambda x: ' '.join(x))
f1_phrase,genre_phrase, predict_genre_phrase = model(phrases_joined,df['genres'])

# %%
#f1_score_summary,f1_score_phrase
f1_summary
# Out:
# 0.32884236708467196

# %%
predict_genre_summary
# Out:
# [('Comedy', 'Drama'),
#  (),
#  (),
#  ('Horror',),
#  (),
#  ('Horror', 'Slasher'),
#  ('Comedy',),
#  ('Comedy',),
#  ('Comedy',),
#  ('Horror',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Comedy',),
#  ('Action', 'Horror'),
#  ('Drama', 'Romance'),
#  ('Comedy',),
#  (),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Action', 'Adventure'),
#  (),
#  (),
#  ('Drama',),
#  ('Mystery', 'Thriller'),
#  ('Black-and-white', 'Comedy', 'Romance'),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  (),
#  (),
#  ('Action', 'Crime Fiction', 'Crime Thriller', 'Drama', 'Mystery', 'Thriller'),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Action/Adventure',),
#  ('Documentary',),
#  (),
#  ('Thriller',),
#  ('Action', 'Action/Adventure', 'Western'),
#  ('Adventure', 'Thriller'),
#  (),
#  ('Comedy',),
#  ('Drama', 'Romance'),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Horror', 'Thriller'),
#  ('Drama', 'Japanese', 'World cinema'),
#  (),
#  (),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Action',),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Crime Fiction',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama', 'Romance', 'Romantic drama', 'World cinema'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Animation', 'Comedy', 'Short'),
#  ('Action', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  ('Action', 'Drama'),
#  ('Drama',),
#  ('Action', 'Action/Adventure', 'Drama'),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Comedy', 'Short'),
#  ('Drama',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Action', 'Crime Fiction', 'Thriller'),
#  ('Drama',),
#  ('Adventure', 'Comedy'),
#  ('Crime Fiction', 'Mystery', 'Thriller'),
#  ('Adventure',),
#  ('Action', 'Action/Adventure'),
#  ('Drama',),
#  ('Drama',),
#  ('Horror', 'Science Fiction'),
#  ('Action', 'Action/Adventure', 'World cinema'),
#  ('Drama', 'Romance'),
#  ('War',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Adventure',),
#  ('Drama', 'Mystery', 'Thriller'),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Romance',),
#  ('Drama', 'War'),
#  ('Drama',),
#  ('Comedy',),
#  ('Comedy', 'Drama'),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Adventure',),
#  ('Comedy',),
#  (),
#  ('Animation', 'Comedy', 'Short'),
#  ('Chinese',),
#  (),
#  (),
#  ('Horror',),
#  ('Science Fiction',),
#  (),
#  ('Drama',),
#  ('Horror',),
#  ('Short',),
#  ('Action', 'Action/Adventure', 'Chinese', 'Martial Arts', 'World cinema'),
#  ('Animation', 'Comedy', 'Short'),
#  ('Documentary',),
#  ('Comedy',),
#  (),
#  ('Comedy',),
#  (),
#  ('Romance',),
#  ('Comedy',),
#  ('Comedy', 'Family'),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Horror',),
#  ('Drama',),
#  (),
#  ('Science Fiction',),
#  ('Romance',),
#  ('Western',),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Action', 'Thriller'),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Documentary',),
#  ('Western',),
#  (),
#  ('Action', 'Drama', 'Thriller'),
#  ('Comedy', 'Drama', 'World cinema'),
#  ('Action', 'Action/Adventure', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Documentary',),
#  ('Drama', 'Romance'),
#  ('Horror',),
#  ('Comedy',),
#  (),
#  ('Comedy', 'Drama'),
#  ('Horror', 'Thriller'),
#  ('Animation', 'Family', 'Short'),
#  ('Drama', 'Romance', 'Romantic drama'),
#  ('Horror', 'Thriller'),
#  ('Drama',),
#  ('Action', 'Chinese'),
#  (),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Animation', 'Fantasy', 'Japanese', 'Science Fiction'),
#  ('Drama',),
#  (),
#  ('Action', 'Thriller'),
#  (),
#  ('Drama', 'Romance', 'World cinema'),
#  (),
#  ('Japanese',),
#  ('Drama',),
#  ('Science Fiction',),
#  (),
#  ('Adventure', 'Horror'),
#  ('Comedy',),
#  ('Action', 'Action/Adventure', 'Thriller'),
#  ('Comedy', 'Musical'),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Comedy', 'Drama'),
#  ('Drama', 'War'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Comedy', 'Drama'),
#  ('Horror',),
#  (),
#  ('Drama',),
#  (),
#  ('Action', 'Action/Adventure', 'Crime Fiction', 'Thriller'),
#  ('Comedy', 'Family'),
#  ('Drama',),
#  ('Action', 'Drama'),
#  ('Action',),
#  ('Action',),
#  ('Comedy', 'Drama'),
#  ('Action', 'Adventure'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama',),
#  ('Action', 'Comedy', 'Crime Fiction'),
#  (),
#  (),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Horror', 'Thriller'),
#  (),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Action', 'Horror', 'Science Fiction', 'Thriller'),
#  (),
#  ('Adventure',),
#  (),
#  ('Action', 'Action/Adventure', 'Thriller'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Action', 'Japanese', 'Science Fiction'),
#  ('Drama',),
#  ('Bollywood', 'Drama', 'World cinema'),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Action', 'Thriller'),
#  ('Drama', 'War'),
#  ('Comedy',),
#  ('Action',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Thriller',),
#  (),
#  ('Drama', 'World cinema'),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Comedy',),
#  ('Comedy', 'Romance'),
#  (),
#  (),
#  (),
#  ('Action',),
#  ('Drama',),
#  (),
#  ('Horror', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Adventure',),
#  ('Comedy', 'Short'),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Comedy', 'Drama'),
#  ('Adventure', 'Fantasy', 'Science Fiction'),
#  ('Comedy', 'Crime Fiction'),
#  (),
#  (),
#  ('War',),
#  ('Action', 'Action/Adventure', 'Western'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'Thriller'),
#  (),
#  ('Romance',),
#  ('Horror',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Horror',),
#  ('Drama',),
#  (),
#  ('Action', 'Adventure', 'Science Fiction'),
#  (),
#  ('Black-and-white', 'Horror'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Drama',),
#  ('Thriller',),
#  ('Drama', 'War'),
#  (),
#  ('Drama', 'Romance'),
#  ('Romance',),
#  ('Crime Fiction', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Comedy', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Comedy', 'Sports'),
#  (),
#  ('Drama', 'Period piece'),
#  (),
#  ('Horror',),
#  ('Crime Fiction', 'Crime Thriller', 'Horror', 'Thriller'),
#  (),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Adventure', 'Family'),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Crime Fiction', 'Drama'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Japanese',),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  (),
#  ('Horror',),
#  (),
#  ('Drama', 'Thriller'),
#  ('Drama',),
#  ('Horror', 'Zombie'),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Action',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama', 'War'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Black-and-white', 'Comedy'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Thriller',),
#  (),
#  ('Drama',),
#  (),
#  ('Science Fiction',),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Short',),
#  ('Comedy', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Fantasy',),
#  (),
#  ('Drama', 'World cinema'),
#  ('Animation', 'Comedy', 'Short'),
#  (),
#  ('Western',),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Drama',),
#  ('Action', 'Action/Adventure'),
#  (),
#  ('Drama',),
#  ('Science Fiction',),
#  (),
#  (),
#  ('Comedy',),
#  ('Drama', 'World cinema'),
#  ('Action', 'Action/Adventure', 'Science Fiction'),
#  ('Comedy',),
#  ('Black-and-white', 'Drama'),
#  (),
#  (),
#  ('Comedy', 'Family'),
#  ('Drama', 'Romance'),
#  ('Comedy',),
#  (),
#  (),
#  ('Thriller',),
#  ('Drama',),
#  (),
#  ('Horror', 'Mystery', 'Psychological thriller', 'Thriller'),
#  ('Comedy',),
#  ('Drama',),
#  ('Romance', 'World cinema'),
#  ('Comedy', 'Crime Fiction', 'Drama'),
#  ('Black-and-white',),
#  ('Sports',),
#  ('Comedy', 'Drama', 'Romance'),
#  (),
#  ('Crime Fiction', 'Drama'),
#  ('Thriller',),
#  ('Drama',),
#  (),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Drama',),
#  ('Family', 'Science Fiction'),
#  (),
#  ('Drama', 'Thriller', 'World cinema'),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Crime Fiction',),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Comedy',),
#  ('Drama', 'War'),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'World cinema'),
#  ('Drama',),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  (),
#  (),
#  ('Comedy', 'Romance'),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Animation', 'Short'),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Action', 'Spy', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Action',),
#  (),
#  (),
#  ('Drama',),
#  ('Creature', 'Horror', 'Science Fiction'),
#  ('Drama',),
#  ('Comedy', 'Short'),
#  ('Action',),
#  ('Documentary',),
#  ('Action',),
#  ('Comedy',),
#  (),
#  ('Action',),
#  ('Drama', 'Romance', 'World cinema'),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Action', 'Thriller'),
#  ('Comedy',),
#  ('Comedy',),
#  (),
#  (),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Action',),
#  ('Horror',),
#  ('Drama',),
#  (),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  ('Action/Adventure', 'Western'),
#  ('Crime Fiction',),
#  ('Horror', 'Thriller'),
#  ('Animation', 'Comedy', 'Short'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Horror', 'World cinema'),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Action/Adventure', 'Adventure'),
#  ('Horror', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Action', 'Action/Adventure', 'Thriller'),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Action', 'Action/Adventure', 'Adventure', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama', 'Romance'),
#  (),
#  ('Drama', 'Thriller'),
#  (),
#  ('Comedy', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Crime Fiction', 'Drama'),
#  (),
#  ('Drama',),
#  ('Comedy', 'Family'),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  ('Comedy', 'Romance'),
#  (),
#  ('Comedy',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Comedy',),
#  ('Action', 'Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama',),
#  (),
#  ('Science Fiction',),
#  (),
#  (),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Crime Fiction', 'Crime Thriller', 'Mystery', 'Thriller'),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama', 'War'),
#  (),
#  (),
#  ('Comedy', 'Romance', 'World cinema'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Comedy',),
#  ('Drama', 'Romance'),
#  ('Comedy', 'Drama', 'Romance', 'World cinema'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Documentary',),
#  ('Action', 'Drama'),
#  ('Comedy',),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Comedy',),
#  ('Comedy',),
#  (),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Western',),
#  (),
#  ('Thriller',),
#  ('Drama',),
#  ('Documentary',),
#  (),
#  ('Action/Adventure', 'Western'),
#  (),
#  ('Drama',),
#  ('Bollywood', 'Drama', 'Romance', 'World cinema'),
#  ('Horror', 'Thriller'),
#  ('Drama', 'Romance'),
#  ('Short',),
#  ('Action',),
#  ('Drama',),
#  (),
#  ('Crime Fiction', 'Drama'),
#  ('Thriller',),
#  ('Crime Fiction', 'Thriller'),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Action', 'War'),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Bollywood', 'Drama'),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama', 'Thriller'),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Adventure',),
#  (),
#  (),
#  ('Romance',),
#  ('Drama',),
#  ('Horror', 'Science Fiction'),
#  ('Drama',),
#  ('Drama', 'Romance', 'World cinema'),
#  ('Crime Fiction', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Action',),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Drama',),
#  ('Action', 'Horror', 'Science Fiction', 'Thriller'),
#  ('Comedy',),
#  ('Comedy',),
#  ('Family',),
#  ('Action', 'Thriller'),
#  ('Drama',),
#  (),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  (),
#  ('Action',),
#  ('Drama',),
#  ('Comedy',),
#  ('Comedy', 'World cinema'),
#  ('Drama',),
#  ('Horror',),
#  ('Drama', 'Science Fiction'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Romance',),
#  ('Drama', 'World cinema'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'War'),
#  (),
#  ('Drama',),
#  ('Horror', 'Science Fiction'),
#  (),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama', 'World cinema'),
#  ('Drama',),
#  (),
#  (),
#  ('Crime Fiction', 'Drama'),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama', 'Romance'),
#  ('Action',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  ('Adventure',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Action', 'Adventure'),
#  ('Chinese', 'World cinema'),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  ('Action', 'Action/Adventure', 'Crime Fiction', 'Thriller'),
#  ('Drama', 'World cinema'),
#  (),
#  ('Drama',),
#  ('Animation', 'Comedy', 'Short'),
#  (),
#  (),
#  (),
#  ('Comedy', 'Romance'),
#  ('Family', 'Fantasy'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  (),
#  (),
#  ('Comedy',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Science Fiction',),
#  ('Comedy',),
#  (),
#  ('Drama', 'Horror', 'Mystery', 'Thriller'),
#  ('Comedy', 'Drama', 'Musical'),
#  ('Action', 'Comedy'),
#  ('Action',),
#  ('Comedy', 'Drama'),
#  ('Action', 'Drama', 'Thriller'),
#  ('Drama',),
#  ('Science Fiction',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Black-and-white', 'Comedy'),
#  ('Drama',),
#  ('Adventure',),
#  (),
#  ('Thriller',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Horror',),
#  ('Drama',),
#  ('War',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Horror', 'Science Fiction'),
#  ('Drama',),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Documentary',),
#  ('Thriller',),
#  (),
#  ('Thriller',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  (),
#  ('Action',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Adventure', 'Science Fiction'),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Horror', 'Science Fiction'),
#  ('Drama',),
#  ('Crime Fiction', 'Mystery', 'Thriller'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Crime Fiction', 'Crime Thriller', 'Drama', 'Mystery', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Comedy',),
#  (),
#  ('Adventure',),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  (),
#  ('Crime Fiction', 'Drama'),
#  ('Drama',),
#  (),
#  ('Horror', 'Thriller'),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Adventure',),
#  ('Comedy', 'Documentary'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Adventure',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('War',),
#  ('Comedy', 'Romance'),
#  ('Action',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Romance'),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Chinese',),
#  ('Comedy', 'Drama'),
#  ('Adventure',),
#  ('Drama', 'Romance'),
#  ('Horror',),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ...]

# %%
predict_genre_phrase
# Out:
# [('Drama',),
#  (),
#  (),
#  (),
#  ('Adventure', 'Fantasy'),
#  ('Comedy',),
#  ('Comedy',),
#  (),
#  (),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  (),
#  ('Animation', 'Short'),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Action', 'Action/Adventure'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Romance',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Action', 'Science Fiction', 'Thriller'),
#  ('Action', 'Crime Fiction', 'Crime Thriller', 'Drama', 'Thriller'),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Horror',),
#  (),
#  ('Action/Adventure',),
#  ('Documentary',),
#  (),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Action', 'Action/Adventure', 'Western'),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Adventure',),
#  ('Adventure', 'Comedy'),
#  ('Comedy', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Horror', 'Thriller'),
#  ('Drama', 'World cinema'),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Action', 'Crime Fiction'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy', 'Crime Fiction'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Action', 'Western'),
#  ('Animation', 'Comedy'),
#  ('Drama', 'War'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  (),
#  ('Action',),
#  ('Drama',),
#  ('Action',),
#  ('Action', 'Action/Adventure', 'Thriller', 'War'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'Thriller'),
#  ('Drama',),
#  ('Short',),
#  ('Drama',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Thriller',),
#  (),
#  ('Adventure',),
#  ('Crime Fiction', 'Mystery', 'Thriller'),
#  ('Adventure', 'Comedy'),
#  ('Western',),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  (),
#  ('War',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Adventure',),
#  ('Comedy',),
#  (),
#  ('Animation', 'Short'),
#  ('Comedy',),
#  (),
#  (),
#  ('Horror',),
#  ('Science Fiction',),
#  ('Drama', 'Family'),
#  ('Drama',),
#  ('Horror',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Chinese', 'Martial Arts', 'World cinema'),
#  ('Animation', 'Comedy', 'Short'),
#  (),
#  ('Comedy',),
#  (),
#  ('Comedy',),
#  (),
#  (),
#  ('Comedy',),
#  ('Comedy',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Action', 'Science Fiction', 'Thriller'),
#  ('Comedy', 'Romance'),
#  (),
#  ('Crime Fiction', 'Drama'),
#  ('Crime Fiction', 'Mystery', 'Thriller'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Documentary',),
#  ('Western',),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Action', 'Action/Adventure', 'Thriller'),
#  ('Drama', 'Japanese', 'World cinema'),
#  ('Drama', 'Romance'),
#  ('Comedy', 'Drama'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Horror',),
#  (),
#  ('Drama',),
#  ('Horror',),
#  (),
#  ('Action', 'Chinese'),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Action', 'Science Fiction'),
#  ('Drama',),
#  ('Drama',),
#  ('Action', 'Thriller'),
#  (),
#  ('Drama', 'Romance'),
#  ('Horror',),
#  ('Japanese', 'World cinema'),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  ('Adventure', 'Horror'),
#  (),
#  ('Action', 'Action/Adventure'),
#  ('Comedy', 'Musical'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Crime Fiction', 'Drama'),
#  ('Comedy', 'Drama', 'LGBT', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Romance',),
#  ('Comedy',),
#  ('Drama', 'War'),
#  (),
#  ('Family',),
#  (),
#  (),
#  ('Comedy', 'Drama'),
#  ('Horror',),
#  (),
#  ('Crime Fiction',),
#  (),
#  ('Action', 'Action/Adventure', 'Crime Fiction', 'Thriller'),
#  ('Animation', 'Comedy', 'Family'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Comedy', 'Drama'),
#  ('Action', 'Thriller'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  (),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Horror', 'Thriller'),
#  (),
#  ('Comedy',),
#  ('Crime Fiction', 'Drama'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Action', 'Adventure', 'Science Fiction'),
#  ('Drama',),
#  ('Action', 'Action/Adventure', 'Adventure'),
#  ('Drama',),
#  ('Action', 'Action/Adventure', 'Thriller'),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Action',),
#  ('Drama', 'War'),
#  ('Comedy',),
#  (),
#  (),
#  (),
#  ('Action',),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  (),
#  (),
#  (),
#  ('Comedy',),
#  (),
#  ('Comedy',),
#  (),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Short'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Horror', 'Mystery', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  ('Comedy', 'Crime Fiction'),
#  ('Drama',),
#  ('Drama',),
#  ('War',),
#  ('Action', 'Action/Adventure', 'Comedy', 'Western'),
#  ('Drama',),
#  ('Drama', 'Japanese'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Science Fiction',),
#  (),
#  (),
#  ('Drama', 'Japanese'),
#  ('Drama',),
#  ('Romance',),
#  ('Horror',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Family'),
#  ('Action', 'Horror', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Adventure',),
#  (),
#  ('Drama', 'Thriller'),
#  (),
#  ('Western',),
#  ('Drama',),
#  ('Drama',),
#  ('Animation', 'Comedy', 'Short'),
#  ('Drama',),
#  ('Horror',),
#  ('Drama', 'War'),
#  (),
#  (),
#  ('Comedy', 'Romance'),
#  ('Crime Fiction', 'Crime Thriller', 'Drama', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Thriller',),
#  ('Animation', 'Comedy'),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Adventure',),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Japanese',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Horror', 'Thriller'),
#  ('Crime Fiction',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Horror'),
#  (),
#  ('Drama',),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Romance',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Family',),
#  (),
#  ('Comedy',),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama', 'War'),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Thriller'),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Comedy',),
#  ('Thriller',),
#  (),
#  ('Drama', 'Japanese'),
#  (),
#  ('Science Fiction',),
#  ('Family',),
#  ('Drama', 'World cinema'),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Action', 'Action/Adventure', 'War'),
#  ('Family',),
#  (),
#  ('Drama', 'World cinema'),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  (),
#  (),
#  ('Comedy',),
#  ('Horror',),
#  ('Drama',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Drama',),
#  ('Horror',),
#  (),
#  ('Drama',),
#  ('Science Fiction',),
#  ('Drama', 'World cinema'),
#  ('Comedy',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Action', 'Action/Adventure', 'Western'),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Comedy', 'Family'),
#  ('Drama', 'Romance'),
#  (),
#  (),
#  ('Drama',),
#  ('Mystery',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'Horror', 'Thriller'),
#  ('Comedy',),
#  (),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Comedy', 'Crime Fiction', 'Drama'),
#  ('Black-and-white', 'Drama'),
#  (),
#  ('Drama', 'Romance'),
#  ('Western',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Action', 'Science Fiction'),
#  (),
#  ('Drama',),
#  ('Animation', 'Fantasy', 'Science Fiction'),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Comedy', 'Crime Fiction'),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Action',),
#  ('Black-and-white', 'Crime Fiction'),
#  ('Drama',),
#  (),
#  (),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Comedy',),
#  ('Drama',),
#  ('Comedy', 'Romance', 'Romantic comedy'),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Thriller',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Horror',),
#  ('Romance',),
#  ('Comedy', 'Short'),
#  ('Action', 'Crime Fiction', 'Thriller'),
#  ('Comedy',),
#  ('Action', 'Action/Adventure', 'Crime Fiction', 'Thriller'),
#  ('Comedy',),
#  (),
#  ('Action',),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Action', 'Thriller'),
#  ('Comedy',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Horror', 'Zombie'),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Western',),
#  ('Crime Fiction', 'Thriller'),
#  ('Horror',),
#  ('Comedy', 'Short'),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Short'),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Horror', 'Mystery', 'Thriller'),
#  (),
#  ('Drama',),
#  ('Action', 'Drama', 'Thriller'),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Adventure', 'Fantasy'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Drama',),
#  ('Romance',),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy',),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Drama',),
#  (),
#  (),
#  ('Comedy',),
#  ('Comedy',),
#  (),
#  ('Comedy',),
#  ('Drama', 'Romance'),
#  (),
#  (),
#  ('Action', 'Action/Adventure', 'Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Japanese',),
#  ('Comedy',),
#  ('Animation',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  (),
#  ('Crime Fiction',),
#  ('Drama', 'War'),
#  (),
#  ('Drama', 'War'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'World cinema'),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  (),
#  ('Drama', 'Romance'),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Horror', 'Thriller'),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Chinese', 'World cinema'),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Western',),
#  (),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  (),
#  ('Documentary',),
#  (),
#  ('Action/Adventure', 'Western'),
#  (),
#  ('Drama',),
#  ('Drama', 'World cinema'),
#  ('Action', 'Adventure', 'Horror'),
#  ('Bollywood', 'Drama', 'Romance', 'World cinema'),
#  (),
#  (),
#  ('Drama',),
#  ('Comedy',),
#  ('Action', 'Crime Fiction', 'Drama'),
#  (),
#  (),
#  ('Drama',),
#  ('Horror',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Action', 'Action/Adventure', 'Adventure', 'Drama', 'War'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  (),
#  ('Drama', 'Romance'),
#  (),
#  (),
#  ('Drama', 'Thriller'),
#  (),
#  ('Japanese',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  ('Action',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Horror',),
#  (),
#  ('Drama', 'Romance', 'Romantic drama', 'World cinema'),
#  ('Crime Fiction', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Action', 'Crime Fiction', 'Drama', 'Thriller'),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Drama',),
#  ('Horror', 'Science Fiction'),
#  ('Drama',),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Adventure', 'Animation', 'Family'),
#  ('Action', 'Thriller'),
#  ('Drama',),
#  (),
#  ('Documentary',),
#  ('Comedy', 'Short'),
#  (),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ('Comedy', 'Family'),
#  ('Drama',),
#  ('Drama',),
#  ('Horror',),
#  ('Drama', 'Science Fiction'),
#  ('Comedy',),
#  ('Comedy', 'Drama'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Romance',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama', 'War'),
#  (),
#  ('Drama',),
#  ('Science Fiction',),
#  ('Action', 'Chinese', 'Martial Arts'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Action', 'Chinese', 'Drama', 'Martial Arts', 'World cinema'),
#  ('Action', 'Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama',),
#  (),
#  (),
#  ('Drama',),
#  ('Action', 'Adventure'),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  ('Action', 'Adventure', 'Science Fiction'),
#  (),
#  (),
#  (),
#  ('Comedy', 'Drama'),
#  ('Musical',),
#  ('Drama', 'Romance'),
#  ('Action', 'Adventure'),
#  (),
#  ('Drama', 'Romance'),
#  (),
#  ('Animation', 'Comedy', 'Short'),
#  ('Action', 'Crime Fiction', 'Drama', 'Thriller'),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Comedy', 'Short'),
#  (),
#  (),
#  (),
#  ('Comedy', 'Romance', 'Romantic comedy'),
#  ('Animation', "Children's/Family", 'Family', 'Fantasy'),
#  ('Drama',),
#  ('Comedy', 'Sports'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  (),
#  ('Comedy',),
#  ('Comedy',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Action', 'Thriller'),
#  (),
#  ('Comedy',),
#  ('Action', 'Drama'),
#  ('Drama',),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama', 'Romance'),
#  (),
#  (),
#  ('Action/Adventure', 'Adventure', 'War'),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  ('Action',),
#  ('Drama',),
#  (),
#  (),
#  ('Horror',),
#  ('Drama',),
#  ('Drama', 'War'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Comedy', 'Drama', 'Romance'),
#  ('Drama',),
#  ('Science Fiction', 'Thriller'),
#  ('Drama',),
#  ('Thriller',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Science Fiction',),
#  ('Drama',),
#  ('Crime Thriller', 'Mystery', 'Thriller'),
#  (),
#  ('Comedy',),
#  ('Drama', 'Thriller'),
#  (),
#  (),
#  (),
#  ('Crime Fiction', 'Crime Thriller', 'Drama', 'Horror', 'Mystery', 'Thriller'),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama', 'Romance'),
#  ('Drama',),
#  (),
#  (),
#  (),
#  ('Silent',),
#  ('Drama', 'World cinema'),
#  (),
#  (),
#  ('Drama',),
#  ('Crime Fiction', 'Drama', 'Thriller'),
#  ('Mystery', 'Thriller'),
#  (),
#  ('Horror',),
#  ('Comedy',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Comedy', 'Documentary'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama',),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama', 'Romance'),
#  (),
#  ('Black-and-white', 'Comedy', 'Short'),
#  ('Drama',),
#  (),
#  (),
#  ('Animation', 'Comedy', 'Family', 'Short'),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Romance',),
#  ('Comedy',),
#  ('Comedy', 'Drama'),
#  (),
#  (),
#  ('Comedy',),
#  ('Adventure',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Comedy',),
#  ('Drama',),
#  ('Drama', 'Romance'),
#  ('Romance',),
#  ('Drama',),
#  (),
#  ('Horror',),
#  (),
#  (),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Drama',),
#  ('Comedy', 'Drama'),
#  ...]

# %% [markdown]
# ### Evaluation metrics

# %% [markdown]
# #### percentage of labels that were predicted correctly

# %%
total_label = sum(genres.apply(len))
total_label
# Out:
# 149300

# %%
print(np.sum([len(set(a).intersection(b)) for a, b in zip(pd.Series(predict_genre_phrase), pd.Series(genre_phrase))]))
print(np.sum([len(set(a).intersection(b)) for a, b in zip(pd.Series(predict_genre_summary), pd.Series(genre_summary))]))
print(np.sum([len(set(a).intersection(b))>0 for a, b in zip(pd.Series(predict_genre_phrase), pd.Series(genre_phrase))]))
print(np.sum([len(set(a).intersection(b))>0 for a, b in zip(pd.Series(predict_genre_summary), pd.Series(genre_summary))]))
# Out:
# 5938
# 6346
# 4511
# 4822

# %%
np.sum([len(set(a).intersection(b)) for a, b in zip(pd.Series(predict_genre_summary), pd.Series(genre_summary))])
# Out:
# 6346

# %%
np.sum([len(set(a).intersection(b))>0 for a, b in zip(pd.Series(predict_genre_phrase), pd.Series(genre_phrase))])
# Out:
# 4511

# %%
np.sum([len(set(a).intersection(b))>0 for a, b in zip(pd.Series(predict_genre_summary), pd.Series(genre_summary))])
# Out:
# 4822

# %%
summary_left_out = pd.Series(list(set(b).intersection(a)) for a, b in zip(pd.Series(predict_genre_summary), \
                                                                pd.Series(genre_summary))).explode().value_counts()
phrase_left_out = pd.Series(list(set(b).intersection(a)) for a, b in zip(pd.Series(predict_genre_phrase), \
                                                                pd.Series(genre_phrase))).explode().value_counts()

dstr = pd.Series(genre_summary).explode().value_counts()

# %%
left_out_pctg = (summary_left_out/dstr)
left_out_pctg_phrase = (phrase_left_out/dstr)
left_out_pctg.loc[~left_out_pctg.isnull()].rename('summary_pctg').to_frame().merge(left_out_pctg_phrase.rename('phrase_pctg'),how = 'left',left_index = True, right_index = True)\
.merge(dstr.rename('dstr'),how = 'left',left_index = True,right_index = True).sort_values(ascending = False,by = 'summary_pctg')
# Out:
#                         summary_pctg  phrase_pctg  dstr
# Drama                       0.655065     0.640000  3850
# Comedy                      0.418807     0.334300  2414
# Horror                      0.412736     0.380896   848
# Short                       0.347896     0.330097   618
# War                         0.330097     0.297735   309
# Animation                   0.301031     0.276289   485
# Science Fiction             0.276498     0.269585   434
# Thriller                    0.272209     0.246944  1227
# Action                      0.270175     0.250877  1140
# Documentary                 0.251938     0.135659   258
# Western                     0.215247     0.322870   223
# Chinese                     0.212435     0.207254   193
# Zombie                      0.209302     0.116279    43
# Crime Fiction               0.203202     0.227833   812
# Family                      0.199060     0.180251   638
# Romance                     0.195702     0.180353  1303
# Jungle                      0.181818          NaN    11
# Adventure                   0.148398     0.150084   593
# Martial Arts                0.125000     0.243056   144
# Action/Adventure            0.121083     0.131054   702
# Black-and-white             0.109827     0.083815   692
# Sports                      0.105634     0.147887   142
# Japanese                    0.091667     0.150000   240
# Fantasy                     0.090226     0.090226   399
# World cinema                0.078394     0.040153  1046
# Holiday                     0.071429     0.142857    14
# Mystery                     0.065534     0.050971   412
# Bollywood                   0.051402     0.014019   214
# Spy                         0.041667     0.041667    72
# Musical                     0.037037     0.050109   459
# Crime Thriller              0.031847     0.044586   314
# LGBT                        0.030303     0.066667   165
# Slasher                     0.020000     0.033333   150
# Monster                     0.020000          NaN    50
# Superhero                   0.018182          NaN    55
# Anime                       0.017857          NaN    56
# Romantic drama              0.016729     0.011152   538
# Costume drama               0.016667     0.033333    60
# Teen                        0.015789     0.005263   190
# Slapstick                   0.010526          NaN    95
# Psychological thriller      0.009434     0.009434   212
# Period piece                0.007463     0.003731   268
# Romantic comedy             0.007075     0.033019   424
# Coming-of-age               0.006289          NaN   159
# Biography                   0.004202          NaN   238
# Silent                      0.004167     0.004167   240

# %% [markdown]
# ### Subset of genres

# %%
genre_subset = ['Drama','Comedy','Romance','Thriller','Action','Horror']
df['subset_genres'] = df['genres'].apply(lambda x: [i for i in x if i in genre_subset])
df['subset_genres'] = df['subset_genres'].apply(lambda x: np.nan if len(x)==0 else x)
subset_df = df.dropna(subset = ['subset_genres'])

# %%
subset_df['processed_summary'] = summary_preprocessing(subset_df['summary'])
# subset_labels = genre_to_label(subset_df['subset_genres'])
f1_summary_, genre_summary, predict_genre_summary = model(subset_df['processed_summary'],subset_df['subset_genres'])
# Out:
# [nltk_data] Downloading package stopwords to /home/humiao/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
subset_phrases_joined = subset_df['phrases'].apply(lambda x: ' '.join(x))
f1_phrase_, genre_phrase, predict_genre_phrase = model(subset_phrases_joined,subset_df['subset_genres'])

# %%
print(np.sum([len(set(a).intersection(b)) for a, b in zip(pd.Series(predict_genre_phrase), pd.Series(genre_phrase))]))
print(np.sum([len(set(a).intersection(b)) for a, b in zip(pd.Series(predict_genre_summary), pd.Series(genre_summary))]))
print(np.sum([len(set(a).intersection(b))>0 for a, b in zip(pd.Series(predict_genre_phrase), pd.Series(genre_phrase))]))
print(np.sum([len(set(a).intersection(b))>0 for a, b in zip(pd.Series(predict_genre_summary), pd.Series(genre_summary))]))
# Out:
# 5573
# 5932
# 4930
# 5220

# %% [markdown]
# ### parameter tuning

# %%
def model_gs(summary,genres):
    #tf-idf vectorizer
    multilabel_binarizer = sklearn.preprocessing.MultiLabelBinarizer()
    multilabel_binarizer.fit(genres)
    label = multilabel_binarizer.transform(genres)
    xtrain, xval, ytrain, yval = train_test_split(summary, label, test_size=0.2, random_state=9)
    tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10000)
    xtrain_tfidf = tfidf_vectorizer.fit_transform(xtrain)
    xval_tfidf = tfidf_vectorizer.transform(xval)
    
    #OneVsRest classifier
    

    parameters = {
        "estimator__penalty": ['l1'],
#         "estimator__solver":['newton-cg','lbfgs', 'liblinear', 'sag', 'saga'],
        "estimator__solver":[ 'liblinear', 'lbfgs'],
        "estimator__C":[1,3],
    }
    lr = sklearn.linear_model.LogisticRegression()
    clf = OneVsRestClassifier(lr,n_jobs = 8)
    model_tunning = GridSearchCV(clf, param_grid=parameters,cv = 3, verbose = 3, scoring = 'f1_micro',refit = True)
#     scores = cross_validate(clf, xtrain_tfidf, ytrain, scoring=scoring)
    model_tunning.fit(xtrain_tfidf,ytrain)
#     y_pred = clf.predict(xval_tfidf)
    
    
    #evaluation
#     f1 = sklearn.metrics.f1_score(yval, y_pred, average="micro")
    return model_tunning.best_score_,model_tunning.best_params_, model_tunning.best_estimator_

# %%
score,param,est = model_gs(df['processed_summary'],df['genres'])
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV 1/3] END estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear; total time=  16.3s
# [CV 2/3] END estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear; total time=  16.4s
# [CV 3/3] END estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear; total time=  16.6s
# [CV 1/3] END estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs; total time=   0.9s
# [CV 2/3] END estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs; total time=   1.7s
# [CV 3/3] END estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs; total time=   1.6s
# [CV 1/3] END estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear; total time=  25.3s
# [CV 2/3] END estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear; total time=  23.2s
# [CV 3/3] END estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear; total time=  22.5s
# [CV 1/3] END estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs; total time=   0.9s
# [CV 2/3] END estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs; total time=   1.8s
# [CV 3/3] END estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs; total time=   2.0s

# %%
score
# Out:
# 0.37836532400369743

# %%
param
# Out:
# {'estimator__C': 3,
#  'estimator__penalty': 'l1',
#  'estimator__solver': 'liblinear'}

# %%
est.predict(xval_tfidf)
f1 = sklearn.metrics.f1_score(yval, y_pred, average="micro")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-39-727253baec60> in <module>
# ----> 1 est.predict(xval_tfidf)
#       2 f1 = sklearn.metrics.f1_score(yval, y_pred, average="micro")
#
# NameError: name 'xval_tfidf' is not defined

# %%
score,param = model_gs(df['phrases'].apply(lambda x: ' '.join(x)),labels,df['genres'])
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear, score=0.304, total=   5.4s
# [CV] estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.4s remaining:    0.0s
# [CV]  estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear, score=0.303, total=   5.6s
# [CV] estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   11.1s remaining:    0.0s
# [CV]  estimator__C=1, estimator__penalty=l1, estimator__solver=liblinear, score=0.300, total=   5.7s
# [CV] estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs ..
# [CV]  estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs, score=nan, total=   0.7s
# [CV] estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs ..
# [CV]  estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs, score=nan, total=   1.4s
# [CV] estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs ..
# [CV]  estimator__C=1, estimator__penalty=l1, estimator__solver=lbfgs, score=nan, total=   1.5s
# [CV] estimator__C=1, estimator__penalty=l2, estimator__solver=liblinear
# [CV]  estimator__C=1, estimator__penalty=l2, estimator__solver=liblinear, score=0.278, total=   7.4s
# [CV] estimator__C=1, estimator__penalty=l2, estimator__solver=liblinear
# [CV]  estimator__C=1, estimator__penalty=l2, estimator__solver=liblinear, score=0.278, total=   5.9s
# [CV] estimator__C=1, estimator__penalty=l2, estimator__solver=liblinear
# [CV]  estimator__C=1, estimator__penalty=l2, estimator__solver=liblinear, score=0.277, total=   5.9s
# [CV] estimator__C=1, estimator__penalty=l2, estimator__solver=lbfgs ..
# [CV]  estimator__C=1, estimator__penalty=l2, estimator__solver=lbfgs, score=0.278, total=   7.7s
# [CV] estimator__C=1, estimator__penalty=l2, estimator__solver=lbfgs ..
# [CV]  estimator__C=1, estimator__penalty=l2, estimator__solver=lbfgs, score=0.278, total=   7.2s
# [CV] estimator__C=1, estimator__penalty=l2, estimator__solver=lbfgs ..
# [CV]  estimator__C=1, estimator__penalty=l2, estimator__solver=lbfgs, score=0.277, total=   7.5s
# [CV] estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear
# [CV]  estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear, score=0.350, total=   7.0s
# [CV] estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear
# [CV]  estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear, score=0.349, total=   7.2s
# [CV] estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear
# [CV]  estimator__C=3, estimator__penalty=l1, estimator__solver=liblinear, score=0.349, total=   7.0s
# [CV] estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs ..
# [CV]  estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs, score=nan, total=   0.7s
# [CV] estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs ..
# [CV]  estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs, score=nan, total=   1.7s
# [CV] estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs ..
# [CV]  estimator__C=3, estimator__penalty=l1, estimator__solver=lbfgs, score=nan, total=   1.5s
# [CV] estimator__C=3, estimator__penalty=l2, estimator__solver=liblinear
# [CV]  estimator__C=3, estimator__penalty=l2, estimator__solver=liblinear, score=0.330, total=   8.3s
# [CV] estimator__C=3, estimator__penalty=l2, estimator__solver=liblinear
# [CV]  estimator__C=3, estimator__penalty=l2, estimator__solver=liblinear, score=0.327, total=   7.0s
# [CV] estimator__C=3, estimator__penalty=l2, estimator__solver=liblinear
# [CV]  estimator__C=3, estimator__penalty=l2, estimator__solver=liblinear, score=0.326, total=   6.6s
# [CV] estimator__C=3, estimator__penalty=l2, estimator__solver=lbfgs ..
# [CV]  estimator__C=3, estimator__penalty=l2, estimator__solver=lbfgs, score=0.330, total=  10.1s
# [CV] estimator__C=3, estimator__penalty=l2, estimator__solver=lbfgs ..
# [CV]  estimator__C=3, estimator__penalty=l2, estimator__solver=lbfgs, score=0.327, total=   9.9s
# [CV] estimator__C=3, estimator__penalty=l2, estimator__solver=lbfgs ..
# [CV]  estimator__C=3, estimator__penalty=l2, estimator__solver=lbfgs, score=0.326, total=  10.4s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  2.3min finished

# %%
score
# Out:
# 0.34914278908655466

# %%
param
# Out:
# {'estimator__C': 3,
#  'estimator__penalty': 'l1',
#  'estimator__solver': 'liblinear'}

# %% [markdown]
# ### pick sentence

# %%
import spacy
import numpy as np
import pandas as pd
from tqdm import tqdm
# from pandarallel import pandarallel
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer


spacy_en = spacy.load("en_core_web_sm")


def pick_rep_sentences(row, n=5):
    """
    Pick sentences with highest average sublinear word tf-idfs
    as the representatives of the full text.
    """
    summary, phrases = row.summary, row.phrases

    spacy_doc = spacy_en(summary)
    sents = np.array([s.text for s in spacy_doc.sents])
    if len(sents) <= n:
        return sents
    if not phrases:
        return np.random.choice(sents, n, replace=False)

    cntv = CountVectorizer(vocabulary=phrases)
    tfidf = TfidfTransformer(sublinear_tf=True)
    ranks = (
        tfidf.fit_transform(cntv.fit_transform(sents)).toarray().sum(axis=1)
    )
    ranks /= np.array([len(s) for s in spacy_doc.sents])
    return sents[np.argpartition(-ranks, n)[:n]]

# %%
sents = df.apply(pick_rep_sentences, axis = 1)
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-49-3dee063e1d3c> in <module>
# ----> 1 sents = df.apply(pick_rep_sentences, axis = 1)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-47-a7f02a0d1b35> in pick_rep_sentences(row, n)
#      20     summary, phrases = row.summary, row.phrases
#      21
# ---> 22     spacy_doc = spacy_en(summary)
#      23     sents = np.array([s.text for s in spacy_doc.sents])
#      24     if len(sents) <= n:
#
# /opt/conda/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     987                 error_handler = proc.get_error_handler()
#     988             try:
# --> 989                 doc = proc(doc, **component_cfg.get(name, {}))
#     990             except KeyError as e:
#     991                 # This typically happens if a component is not initialized
#
# /opt/conda/lib/python3.8/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /opt/conda/lib/python3.8/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# /opt/conda/lib/python3.8/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in predict(self, X)
#     310         only the output, instead of the `(output, callback)` tuple.
#     311         """
# --> 312         return self._func(self, X, is_train=False)[0]
#     313
#     314     def finish_update(self, optimizer: Optimizer) -> None:
#
# /opt/conda/lib/python3.8/site-packages/spacy/ml/tb_framework.py in forward(model, X, is_train)
#      29
#      30 def forward(model, X, is_train):
# ---> 31     step_model = ParserStepModel(
#      32         X,
#      33         model.layers,
#
# /opt/conda/lib/python3.8/site-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      38         return model.layers[0](Xseq, is_train)
#      39     else:
# ---> 40         return _list_forward(cast(Model[List2d, List2d], model), Xseq, is_train)
#      41
#      42
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/with_array.py in _list_forward(model, Xs, is_train)
#      74     lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      75     Xf = layer.ops.flatten(Xs, pad=pad)  # type: ignore
# ---> 76     Yf, get_dXf = layer(Xf, is_train)
#      77
#      78     def backprop(dYs: List2d) -> List2d:
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/residual.py in forward(model, X, is_train)
#      38             return d_output + dX
#      39
# ---> 40     Y, backprop_layer = model.layers[0](X, is_train)
#      41     if isinstance(X, list):
#      42         return [X[i] + Y[i] for i in range(len(X))], backprop
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /opt/conda/lib/python3.8/site-packages/thinc/model.py in __call__(self, X, is_train)
#     286         """Call the model's `forward` function, returning the output and a
#     287         callback to compute the gradients via backpropagation."""
# --> 288         return self._func(self, X, is_train=is_train)
#     289
#     290     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.8/site-packages/thinc/layers/maxout.py in forward(model, X, is_train)
#      47     W = model.get_param("W")
#      48     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 49     Y = model.ops.gemm(X, W, trans2=True)
#      50     Y += model.ops.reshape1f(b, nO * nP)
#      51     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
score,param,est = model_gs(sents.apply(lambda x: ' '.join(x)),df['genres'])
